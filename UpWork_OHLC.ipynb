# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticker

# from matplotlib.finance import candlestick_ohlc
import mplfinance as mpf

from matplotlib.pyplot import figure
# %matplotlib inline

# %%
datafile = 'EOD_SQ_daily_ta_values.csv'
data = pd.read_csv(datafile, index_col = 'date')
data.index = pd.to_datetime(data.index) # Converting the dates from string to datetime format
data.head(5)
# Out:
#            symbol  open  high   low  close  pos_3_atr  pos_2_atr  pos_1_atr  \
# date
# 2016-05-17     SQ  8.98  9.56  8.63   9.18  14.604458  13.744444  12.884430
# 2016-05-18     SQ  9.11  9.99  9.11   9.40  14.407255  13.546241  12.685228
# 2016-05-19     SQ  9.36  9.65  9.24   9.60  14.163443  13.324980  12.486518
# 2016-05-20     SQ  9.61  9.66  9.25   9.39  13.919179  13.102139  12.285100
# 2016-05-23     SQ  9.60  9.68  9.40   9.46  13.679756  12.889068  12.098381
#
#                 ema20    sma20  neg_1_atr  neg_2_atr  neg_3_atr  \
# date
# 2016-05-17  11.508407  12.1765  10.132385   9.272371   8.412357
# 2016-05-18  11.307607  11.9650   9.929986   9.068972   8.207959
# 2016-05-19  11.144978  11.7830   9.803437   8.964975   8.126512
# 2016-05-20  10.977837  11.5855   9.670574   8.853534   8.036495
# 2016-05-23  10.833281  11.3790   9.568181   8.777493   7.986806
#
#             bollinger_band_top  bollinger_band_bottom  squeeze_keltner_upper  \
# date
# 2016-05-17           16.561809               7.791191              13.443439
# 2016-05-18           16.456243               7.473757              13.244887
# 2016-05-19           16.347240               7.218760              13.031518
# 2016-05-20           16.204666               6.966334              12.816176
# 2016-05-23           15.990516               6.767484              12.612328
#
#             squeeze_keltner_lower  squeeze_boolean
# date
# 2016-05-17               9.573376            False
# 2016-05-18               9.370327            False
# 2016-05-19               9.258437            False
# 2016-05-20               9.139498            False
# 2016-05-23               9.054234            False

# %%
mpf.plot(data[-120:], type='candlestick', no_xgaps = True)
# Out:
# /usr/local/anaconda3/envs/Covid/lib/python3.7/site-packages/mplfinance/plotting.py:68: DeprecationWarning:
#
#  =================================================================
#
#    WARNING: `no_xgaps` is deprecated:
#      Default value is now `no_xgaps=True`
#      However, to set `no_xgaps=False` and silence this warning,
#      use instead: `show_nontrading=True`.
#
#  ================================================================
#   category=DeprecationWarning)
